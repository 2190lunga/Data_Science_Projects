# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/610063/Downloads/Hex Software Internship/Task 1 Week (30th Dec - 05 Jan 2025)/Titanic Dataset/Titanic Dataset.csv")

# %%
dataset.head() # checking or understanding variables in the dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
dataset.tail() # checking last 5 rows of data
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
dataset.shape # dimensions of the data
# Out:
# (418, 12)

# %%
dataset.describe() # getting the summary statistics from the numerical variables in the dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.nunique() #checking unique values in our data
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
dataset['Pclass'].unique()
dataset['Gender'].unique()

# %%
#Cleaning the data

# %%
 dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset['Age'].fillna(dataset['Age'].mean(), inplace=True) # removing null values for the age variable bu filling them with an average

# %%
new_data = dataset.drop(['Cabin','Embarked' ,'PassengerId','SibSp', 'Parch'  ],axis=1) # removing unnecessary columns

# %%
dataset['Fare'].fillna(dataset['Fare'].mean(), inplace=True)

# %%
new_data.isnull().sum() # All null values has  been removed the data is clean
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# Ticket      0
# Fare        0
# dtype: int64

# %%
#Checking for outliers in the Fare variable using the boxplot 
sns.boxplot(new_data['Fare'])
# Out:
# <Axes: >

# %%
#Checking for outliers in the Age variable using the boxplot 
sns.boxplot(new_data['Age'])
# Out:
# <Axes: >

# %%
#Handling Outliers for Age and Fair columns using IQR Method
q1_Age = new_data['Age'].quantile(0.25)
q3_Age = new_data['Age'].quantile(0.75)
def IQR_Age():
    Q1 = new_data['Age'].quantile(0.25)
    Q3 = new_data['Age'].quantile(0.75)
    IQR = Q3 -Q1
    return IQR

q1_Fare = new_data['Fare'].quantile(0.25)
q3_Fare = new_data['Fare'].quantile(0.75)
def IQR_Fare():
    Q1 = new_data['Fare'].quantile(0.25)
    Q3 = new_data['Fare'].quantile(0.75)
    IQR = Q3 -Q1
    return IQR
IQR_Age(),IQR_Fare()
# Out:
# (12.75, 23.6042)

# %%
# Calculating the Upper and lower limit using IQR to discard outliers in an Age and Fare Variable
Upper_limit_Age = q3_Age + (1.5* IQR_Age())
Lower_limit_Age = q1_Age - (1.5* IQR_Age())
Lower_limit_Age,Upper_limit_Age

Upper_limit_Fare = q3_Fare + (1.5* IQR_Age())
Lower_limit_Fare = q1_Fare - (1.5* IQR_Age())
Lower_limit_Age,Upper_limit_Age
# Out:
# (3.875, 54.875)

# %%
# Finding the outliers in our dataset for Age and Fare variables 
new_data.loc[(new_data['Age'] > Upper_limit_Age) | (new_data['Age'] < Lower_limit_Age)]
# Out:
#      Survived  Pclass                                               Name  \
# 2           0       2                          Myles, Mr. Thomas Francis
# 13          0       2                               Howard, Mr. Benjamin
# 20          0       1                             Rothschild, Mr. Martin
# 48          1       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 69          1       1                Fortune, Mrs. Mark (Mary McDougald)
# 77          1       1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 81          0       1                                 Straus, Mr. Isidor
# 89          0       2                        Wells, Master. Ralph Lester
# 96          1       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 117         1       3                    Sandstrom, Miss. Beatrice Irene
# 142         0       1                         Ryerson, Mr. Arthur Larned
# 152         0       3                                 Storey, Mr. Thomas
# 179         1       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 193         0       2                                  Lingane, Mr. John
# 201         0       3            Danbom, Master. Gilbert Sigvard Emanuel
# 213         1       2       Howard, Mrs. Benjamin (Ellen Truelove Arman)
# 217         0       1                           Wick, Mr. George Dennick
# 236         0       1                           Warren, Mr. Frank Manley
# 240         1       1          Lindstrom, Mrs. Carl Johan (Sigrid Posse)
# 250         1       2                              West, Miss. Barbara J
# 263         1       3                       Klasen, Miss. Gertrud Emilia
# 281         0       3                     Peacock, Master. Alfred Edward
# 284         1       3                        Rosblom, Miss. Salli Helena
# 296         1       2                              Laroche, Miss. Louise
# 305         1       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 307         0       3                          Aks, Master. Philip Frank
# 308         0       1                         Hays, Mr. Charles Melville
# 314         1       1              White, Mrs. John Stuart (Ella Holmes)
# 316         0       1                      Spencer, Mr. William Augustus
# 343         1       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 354         1       3            Dean, Miss. Elizabeth Gladys Millvina""
# 356         1       1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 378         0       1                        Hipkins, Mr. William Edward
# 387         0       2                                    Ashby, Mr. John
# 409         1       3                          Peacock, Miss. Treasteall
#
#         Sex    Age              Ticket        Fare
# 2      male  62.00              240276    9.687500
# 13     male  63.00               24065   26.000000
# 20     male  55.00            PC 17603   59.400000
# 48   female  60.00               11813   76.291700
# 69   female  60.00               19950  263.000000
# 77   female  55.00               11770   25.700000
# 81     male  67.00            PC 17483  221.779200
# 89     male   2.00               29103   23.000000
# 96   female  76.00               19877   78.850000
# 114  female  63.00            PC 17483  221.779200
# 117  female   1.00             PP 9549   16.700000
# 142    male  61.00            PC 17608  262.375000
# 152    male  60.50                3701   35.627188
# 179  female  64.00            PC 17756   83.158300
# 193    male  61.00              235509   12.350000
# 201    male   0.33              347080   14.400000
# 213  female  60.00               24065   26.000000
# 217    male  57.00               36928  164.866700
# 236    male  64.00              110813   75.250000
# 240  female  55.00              112377   27.720800
# 250  female   0.92          C.A. 34651   27.750000
# 263  female   1.00              350405   12.183300
# 281    male   0.75  SOTON/O.Q. 3101315   13.775000
# 284  female   2.00              370129   20.212500
# 296  female   1.00       SC/Paris 2123   41.579200
# 305  female  64.00              112901   26.550000
# 307    male   0.83              392091    9.350000
# 308    male  55.00               12749   93.500000
# 314  female  55.00            PC 17760  135.633300
# 316    male  57.00            PC 17569  146.520800
# 343  female  58.00            PC 17755  512.329200
# 354  female   0.17           C.A. 2315   20.575000
# 356  female  59.00               11769   51.479200
# 378    male  55.00                 680   50.000000
# 387    male  57.00              244346   13.000000
# 409  female   3.00  SOTON/O.Q. 3101315   13.775000

# %%
new_data.loc[(new_data['Fare'] > Upper_limit_Fare) | (new_data['Fare'] < Lower_limit_Fare)]
# Out:
#      Survived  Pclass                                               Name  \
# 12          1       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          1       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 20          0       1                             Rothschild, Mr. Martin
# 23          0       1                    Williams, Mr. Richard Norris II
# 24          1       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# ..        ...     ...                                                ...
# 400         1       1                            Bonnell, Miss. Caroline
# 402         1       1                     Gibson, Miss. Dorothy Winifred
# 407         0       1                         Widener, Mr. George Dunton
# 411         1       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1       1                       Oliva y Ocana, Dona. Fermina
#
#         Sex   Age       Ticket      Fare
# 12   female  23.0        21228   82.2667
# 14   female  47.0  W.E.P. 5734   61.1750
# 20     male  55.0     PC 17603   59.4000
# 23     male  21.0     PC 17597   61.3792
# 24   female  48.0     PC 17608  262.3750
# ..      ...   ...          ...       ...
# 400  female  30.0        36928  164.8667
# 402  female  22.0       112378   59.4000
# 407    male  50.0       113503  211.5000
# 411  female  37.0        19928   90.0000
# 414  female  39.0     PC 17758  108.9000
#
# [79 rows x 7 columns]

# %%
# Remove outliers in the dataset by trimming the data leaving out outliers in the Aage and Fare variables
new_df  = new_data.loc[(new_data['Age'] < Upper_limit_Age) & (new_data['Age'] > Lower_limit_Age)]
print("Old data length",len(new_data))
print("New data length",len(new_df))
# Out:
# Old data length 418
# New data length 382

# %%
final_Data  = new_data.loc[(new_data['Fare'] < Upper_limit_Fare) & (new_data['Fare'] > Lower_limit_Fare)]
print("Old data length",len(new_data))
print("New data length",len(final_Data))
# Out:
# Old data length 418
# New data length 339

# %%
sns.boxplot(final_Data['Fare'])
# Out:
# <Axes: >

# %%
# Exploration of the relationships between the the variables

# %%
sns.pairplot(final_Data)
# Out:
# C:\Users\610063\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\610063\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\610063\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\610063\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.relplot(x='Fare',y='Age',hue='Pclass',data=final_Data)

# %%
sns.distplot(final_Data['Age'] , bins=5)
# Out:
# C:\Users\610063\AppData\Local\Temp\ipykernel_8332\2056280242.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_Data['Age'] , bins=5)
# C:\Users\610063\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# Ticket      0
# Fare        0
# dtype: int64
